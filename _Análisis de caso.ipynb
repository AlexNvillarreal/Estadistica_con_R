# %% [markdown]
# #  Análisis de caso
# ## ESTADISTICAS PARA NEGOCIOS
#
# Unidad 5. Diseño de experimentos
# Actividad 7. Análisis de caso
#
#
#     Alejandra Nohemi Villarreal Barron
#     870140008
#     Ing. Ciencia de Datos
#
#     Docente: Octavio Avila Marron
#
#                                     Monterrey, N.L. México a 5 de diciembre del 2022

# %%
# ggplot2 import
library(ggplot2)

# %%
data <- read_csv('muestraordenada.csv')
data
# Out:
# Rows: 16 Columns: 2
#
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (1): Proveedor
# dbl (1): Viscosidad
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#    Proveedor Viscosidad
# 1  A         98
# 2  A         91
# 3  A         96
# 4  A         95
# 5  B         97
# 6  B         90
# 7  B         95
# 8  B         96
# 9  C         99
# 10 C         93
# 11 C         97
# 12 C         99
# 13 D         96
# 14 D         92
# 15 D         95
# 16 D         98

# %%
library(ggplot2)
p <- ggplot(data, aes(Proveedor)) +
      geom_bar(width=.7) +
      coord_flip() +
      theme(axis.title.y=element_blank())
p
# Out:
# plot without title

# %%
p <- qplot(sample = Viscosidad, 
      data = data,
      color=Proveedor) +
     theme_minimal()
p
# Out:
# plot without title

# %%
#calculate standart deviation
sd.groups <- tapply(X = data$Viscosidad, INDEX = data$Proveedor, FUN = sd)
sd.groups
# Out:
#        A        B        C        D
# 2.943920 3.109126 2.828427 2.500000

# %%
#calculate ratio of the largest to the smallest sample standard deviation
ratio <- max(as.vector(sd.groups)) / min(as.vector(sd.groups))
ratio
# Out:
# [1] 1.243651

# %% [markdown]
# # Hypothesis Testing
#     State the null hypothesis H0 and alternative hypothesis HA

# %%
alpha <- 0.01

# %%
anova <- aov(Viscosidad ~ Proveedor, data = data)
summary(anova)
# Out:
#             Df Sum Sq Mean Sq F value Pr(>F)
# Proveedor    3  14.19   4.729   0.581  0.639
# Residuals   12  97.75   8.146

# %% [markdown]
# ## Se rechaza la hipotesis nula puesto a que p > a, 0.639 > 0.01
#
# #                                      FIN
